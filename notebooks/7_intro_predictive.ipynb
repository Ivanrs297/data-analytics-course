# %%
from sklearn.datasets import make_regression


X, y = make_regression(n_features=1, noise = 30, random_state=0)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
import pandas as pd

df = pd.DataFrame(X)
df.columns = ["x"]
df["y"] = y
df
# Out:
#            x          y
# 0  -1.141503 -41.281963
# 1   0.632374  50.197835
# 2   1.025658  12.563188
# 3  -0.287310  -0.036414
# 4   0.944833  31.694716
# ..       ...        ...
# 95 -0.717414 -13.347252
# 96  0.177024  -5.440208
# 97  1.703203  44.740870
# 98 -0.845535 -35.557129
# 99  0.060708  24.935482
#
# [100 rows x 2 columns]

# %%
df["x"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np

y_mean = np.array([y.mean()] * 100)
# Out:
# (100,)

# %%
from sklearn.linear_model import LinearRegression

model_1 = LinearRegression()
model_2 = LinearRegression()
model_3 = LinearRegression()

model_1.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model_1.predict(X)

# %%
import matplotlib.pyplot as plt

X, y = make_regression(n_features=1, noise = 30, random_state=0)

# Selector
plt.figure(figsize=(10, 4))

# Data
plt.scatter(X, y, label = "Random Data")
# Simple model mean
plt.plot(X, y_mean, label = "Mean", c="green")
# Linear Regression
plt.plot(X, y_pred, label = "Linear Regression", c="red")

# Show
plt.xlabel("Features (x)")
plt.ylabel("Target (y)")
plt.title("Scatter Example Plot")
plt.legend()
plt.savefig("../reports/figures/random1.svg")

# %% [markdown]
# # Activity
#
# - Dataset: Boston Housing
# - X: Top-1 correlate feature with target
# - Target: MEDV
# - Model: Linear Regression
# - Send figure with your name in the Title
